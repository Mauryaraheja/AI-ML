# %%
#In this we will see , how to load json files into the pandas
#JSON - java script object notation , whenever we fetch data from api it gives data in json format that can be used by any language , that's whey json format is used
import pandas as pd

# %%
pd.read_json('.json')

# %%
#if to fetch directly from url
pd.read_json('url')

# %%
#Working with sql
#Steps :
# !pip install mysql.connector

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host='localhost',user='root',password=' ',database='name_of_database')

# %%
pd.read_sql_query("SELECT * FROM table_name",conn)
